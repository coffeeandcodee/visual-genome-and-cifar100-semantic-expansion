# %%
 # ============================================================================
# GENERATE MORE DESCRIPTIONS USING OLLAMA
# ============================================================================
# Priority order:
#   1. CIFAR-100 words NOT in checkpoint (missing entirely)
#   2. Words with fewest descriptions (need more)
#
# Generates 100 descriptions per word, then moves to next word.
# Saves checkpoint after each word for safety.
# ============================================================================

import json
import requests
import re
import torchvision

CHECKPOINT_FILE = "more_words.json"
OLLAMA_URL = "http://localhost:11434/api/generate"
TARGET_PER_WORD = 100  # Generate 100 descriptions per run

# Load checkpoint
with open(CHECKPOINT_FILE, 'r') as f:
    checkpoint = json.load(f)

# Get all CIFAR-100 words
cifar100 = torchvision.datasets.CIFAR100(root='./data', download=True)
all_cifar_words = set(cifar100.classes)

# Find words missing from checkpoint entirely
checkpoint_words = set(checkpoint['descriptions'].keys())
missing_words = sorted(all_cifar_words - checkpoint_words)

# Get words sorted by description count (fewest first)
existing_counts = [(word, len(checkpoint['descriptions'].get(word, []))) 
                   for word in all_cifar_words if word in checkpoint_words]
existing_counts.sort(key=lambda x: x[1])

# Build priority queue: missing words first, then by count
words_to_process = missing_words + [w for w, c in existing_counts]

print(f"Checkpoint has {len(checkpoint_words)} words")
print(f"Missing from checkpoint: {len(missing_words)} words: {missing_words}")
print(f"\nWill generate {TARGET_PER_WORD} descriptions per word")
print("="*60)

def clean_description(desc, word):
    """Clean and validate a description."""
    desc = desc.lower().strip()
    desc = desc.strip('"\'')
    desc = re.sub(r'^[\d\.\)\-\*]+\s*', '', desc)  # Remove numbering
    desc = re.sub(r'_([a-z]+)_', r'\1', desc)  # Strip markdown underscores
    desc = re.sub(r"(\b\w+)'s\b", r'\1', desc)  # Strip possessives
    
    # Normalize compound words
    compounds = [
        ('aquarium fish', 'aquarium_fish'), ('lawn mower', 'lawn_mower'),
        ('maple tree', 'maple_tree'), ('oak tree', 'oak_tree'),
        ('palm tree', 'palm_tree'), ('pickup truck', 'pickup_truck'),
        ('pine tree', 'pine_tree'), ('sweet pepper', 'sweet_pepper'),
        ('willow tree', 'willow_tree'),
    ]
    for space_ver, under_ver in compounds:
        desc = desc.replace(space_ver, under_ver)
    
    # Validate
    word_check = word.replace('_', ' ') if '_' in word else word
    if word not in desc and word_check not in desc:
        return None
    if len(desc) < 10 or len(desc) > 200:
        return None
    return desc

# Generate descriptions
for i, word in enumerate(words_to_process):
    existing = len(checkpoint['descriptions'].get(word, []))
    print(f"[{i+1}/{len(words_to_process)}] {word} (existing: {existing})...", end=" ", flush=True)
    
    new_descriptions = set()
    batch_num = 0
    
    while len(new_descriptions) < TARGET_PER_WORD and batch_num < 15:
        batch_num += 1
        
        prompt = f"""Generate 50 unique short image captions that a HUMAN would write to describe a photograph containing "{word}".

Rules:
- 4-8 words each
- Use the exact word "{word}". KEEP UNDERSCORE IF PRESENT!
- The word needs to appear EXACTLY as mentioned in the description, without alternative (e.g use bed and not bedside)
- Write like a human describing what they SEE in a real photograph
- Varied contexts, colors, actions, settings
- Natural language, not robotic or repetitive
- Output ONLY the captions, one per line. No numbers, bullets, or explanations.
"""

        try:
            response = requests.post(OLLAMA_URL, json={
                "model": "llama3.2",
                "prompt": prompt,
                "stream": False
            }, timeout=120)
            
            result = response.json()
            text = result.get('response', '')
            
            for line in text.strip().split('\n'):
                cleaned = clean_description(line, word)
                if cleaned:
                    new_descriptions.add(cleaned)
                    
        except Exception as e:
            print(f"Error: {e}", end=" ", flush=True)
            break
    
    # Append to checkpoint
    if word not in checkpoint['descriptions']:
        checkpoint['descriptions'][word] = []
    
    new_list = list(new_descriptions)
    checkpoint['descriptions'][word].extend(new_list)
    
    # Save checkpoint after each word
    with open(CHECKPOINT_FILE, 'w') as f:
        json.dump(checkpoint, f)
    
    new_total = len(checkpoint['descriptions'][word])
    print(f"✓ +{len(new_list)} new (total: {new_total})")

print(f"\n{'='*60}")
print(f"✓ Done! Checkpoint updated.")
print(f"  Words in checkpoint: {len(checkpoint['descriptions'])}")
# Out:
# 100%|██████████| 169M/169M [00:17<00:00, 9.63MB/s]
# Checkpoint has 0 words
# Missing from checkpoint: 100 words: ['apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock', 'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur', 'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion', 'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse', 'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine', 'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose', 'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table', 'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout', 'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman', 'worm']
#
# Will generate 100 descriptions per word
# ============================================================
# [1/100] apple (existing: 0)... ✓ +129 new (total: 129)
# [2/100] aquarium_fish (existing: 0)... ✓ +100 new (total: 100)
# [3/100] baby (existing: 0)... ✓ +108 new (total: 108)
# [4/100] bear (existing: 0)... ✓ +105 new (total: 105)
# [5/100] beaver (existing: 0)... ✓ +102 new (total: 102)
# [6/100] bed (existing: 0)... ✓ +131 new (total: 131)
# [7/100] bee (existing: 0)... ✓ +147 new (total: 147)
# [8/100] beetle (existing: 0)... ✓ +100 new (total: 100)
# [9/100] bicycle (existing: 0)... ✓ +131 new (total: 131)
# [10/100] bottle (existing: 0)... ✓ +111 new (total: 111)
# [11/100] bowl (existing: 0)... ✓ +132 new (total: 132)
# [12/100] boy (existing: 0)... ✓ +135 new (total: 135)
# [13/100] bridge (existing: 0)... ✓ +113 new (total: 113)
# [14/100] bus (existing: 0)... ✓ +113 new (total: 113)
# [15/100] butterfly (existing: 0)... ✓ +146 new (total: 146)
# [16/100] camel (existing: 0)... ✓ +134 new (total: 134)
# [17/100] can (existing: 0)... ✓ +149 new (total: 149)
# [18/100] castle (existing: 0)... ✓ +133 new (total: 133)
# [19/100] caterpillar (existing: 0)... ✓ +125 new (total: 125)
# [20/100] cattle (existing: 0)... ✓ +127 new (total: 127)
# [21/100] chair (existing: 0)... ✓ +121 new (total: 121)
# [22/100] chimpanzee (existing: 0)... ✓ +139 new (total: 139)
# [23/100] clock (existing: 0)... ✓ +112 new (total: 112)
# [24/100] cloud (existing: 0)... ✓ +114 new (total: 114)
# [25/100] cockroach (existing: 0)... ✓ +147 new (total: 147)
# [26/100] couch (existing: 0)... ✓ +104 new (total: 104)
# [27/100] crab (existing: 0)... ✓ +135 new (total: 135)
# [28/100] crocodile (existing: 0)... ✓ +129 new (total: 129)
# [29/100] cup (existing: 0)... ✓ +129 new (total: 129)
# [30/100] dinosaur (existing: 0)... ✓ +103 new (total: 103)
# [31/100] dolphin (existing: 0)... ✓ +108 new (total: 108)
# [32/100] elephant (existing: 0)... ✓ +107 new (total: 107)
# [33/100] flatfish (existing: 0)... ✓ +120 new (total: 120)
# [34/100] forest (existing: 0)... ✓ +107 new (total: 107)
# [35/100] fox (existing: 0)... ✓ +110 new (total: 110)
# [36/100] girl (existing: 0)... ✓ +101 new (total: 101)
# [37/100] hamster (existing: 0)... ✓ +115 new (total: 115)
# [38/100] house (existing: 0)... ✓ +101 new (total: 101)
# [39/100] kangaroo (existing: 0)... ✓ +140 new (total: 140)
# [40/100] keyboard (existing: 0)... ✓ +130 new (total: 130)
# [41/100] lamp (existing: 0)... ✓ +121 new (total: 121)
# [42/100] lawn_mower (existing: 0)... ✓ +132 new (total: 132)
# [43/100] leopard (existing: 0)... ✓ +131 new (total: 131)
# [44/100] lion (existing: 0)... ✓ +130 new (total: 130)
# [45/100] lizard (existing: 0)... ✓ +100 new (total: 100)
# [46/100] lobster (existing: 0)... ✓ +142 new (total: 142)
# [47/100] man (existing: 0)... ✓ +102 new (total: 102)
# [48/100] maple_tree (existing: 0)... ✓ +136 new (total: 136)
# [49/100] motorcycle (existing: 0)... ✓ +131 new (total: 131)
# [50/100] mountain (existing: 0)... ✓ +127 new (total: 127)
# [51/100] mouse (existing: 0)... ✓ +115 new (total: 115)
# [52/100] mushroom (existing: 0)... ✓ +146 new (total: 146)
# [53/100] oak_tree (existing: 0)... ✓ +100 new (total: 100)
# [54/100] orange (existing: 0)... ✓ +127 new (total: 127)
# [55/100] orchid (existing: 0)... ✓ +120 new (total: 120)
# [56/100] otter (existing: 0)... ✓ +100 new (total: 100)
# [57/100] palm_tree (existing: 0)... ✓ +131 new (total: 131)
# [58/100] pear (existing: 0)... ✓ +101 new (total: 101)
# [59/100] pickup_truck (existing: 0)... ✓ +102 new (total: 102)
# [60/100] pine_tree (existing: 0)... ✓ +121 new (total: 121)
# [61/100] plain (existing: 0)... ✓ +103 new (total: 103)
# [62/100] plate (existing: 0)... ✓ +148 new (total: 148)
# [63/100] poppy (existing: 0)... ✓ +124 new (total: 124)
# [64/100] porcupine (existing: 0)... ✓ +112 new (total: 112)
# [65/100] possum (existing: 0)... ✓ +108 new (total: 108)
# [66/100] rabbit (existing: 0)... ✓ +103 new (total: 103)
# [67/100] raccoon (existing: 0)... ✓ +129 new (total: 129)
# [68/100] ray (existing: 0)... ✓ +115 new (total: 115)
# [69/100] road (existing: 0)... ✓ +125 new (total: 125)
# [70/100] rocket (existing: 0)... ✓ +113 new (total: 113)
# [71/100] rose (existing: 0)... ✓ +120 new (total: 120)
# [72/100] sea (existing: 0)... ✓ +115 new (total: 115)
# [73/100] seal (existing: 0)... ✓ +116 new (total: 116)
# [74/100] shark (existing: 0)... ✓ +100 new (total: 100)
# [75/100] shrew (existing: 0)... ✓ +136 new (total: 136)
# [76/100] skunk (existing: 0)... ✓ +125 new (total: 125)
# [77/100] skyscraper (existing: 0)... ✓ +142 new (total: 142)
# [78/100] snail (existing: 0)... ✓ +144 new (total: 144)
# [79/100] snake (existing: 0)... ✓ +114 new (total: 114)
# [80/100] spider (existing: 0)... ✓ +128 new (total: 128)
# [81/100] squirrel (existing: 0)... ✓ +105 new (total: 105)
# [82/100] streetcar (existing: 0)... ✓ +100 new (total: 100)
# [83/100] sunflower (existing: 0)... ✓ +137 new (total: 137)
# [84/100] sweet_pepper (existing: 0)... ✓ +130 new (total: 130)
# [85/100] table (existing: 0)... ✓ +100 new (total: 100)
# [86/100] tank (existing: 0)... ✓ +124 new (total: 124)
# [87/100] telephone (existing: 0)... ✓ +116 new (total: 116)
# [88/100] television (existing: 0)... ✓ +117 new (total: 117)
# [89/100] tiger (existing: 0)... ✓ +134 new (total: 134)
# [90/100] tractor (existing: 0)... ✓ +111 new (total: 111)
# [91/100] train (existing: 0)... ✓ +109 new (total: 109)
# [92/100] trout (existing: 0)... ✓ +116 new (total: 116)
# [93/100] tulip (existing: 0)... ✓ +103 new (total: 103)
# [94/100] turtle (existing: 0)... ✓ +111 new (total: 111)
# [95/100] wardrobe (existing: 0)... ✓ +100 new (total: 100)
# [96/100] whale (existing: 0)... ✓ +104 new (total: 104)
# [97/100] willow_tree (existing: 0)... ✓ +156 new (total: 156)
# [98/100] wolf (existing: 0)... ✓ +133 new (total: 133)
# [99/100] woman (existing: 0)... ✓ +107 new (total: 107)
# [100/100] worm (existing: 0)... ✓ +108 new (total: 108)
#
# ============================================================
# ✓ Done! Checkpoint updated.
#   Words in checkpoint: 100

# %%
# DESCRIPTIONS PER WORD
import json
import torchvision

CHECKPOINT_FILE = "more_words.json"

with open(CHECKPOINT_FILE, 'r') as f:
    checkpoint = json.load(f)

cifar100 = torchvision.datasets.CIFAR100(root='./data', download=False)
all_cifar_words = sorted(cifar100.classes)

print(f"{'Word':<20} {'Count':>6}")
print("=" * 28)

total = 0
for word in all_cifar_words:
    count = len(checkpoint['descriptions'].get(word, []))
    total += count
    print(f"{word:<20} {count:>6}")

print("=" * 28)
print(f"{'TOTAL':<20} {total:>6}")
print(f"\nWords with descriptions: {len(checkpoint['descriptions'])}/100")
# Out:
# Word                  Count
# ============================
# apple                   129
# aquarium_fish           100
# baby                    108
# bear                    105
# beaver                  102
# bed                     131
# bee                     147
# beetle                  100
# bicycle                 131
# bottle                  111
# bowl                    132
# boy                     135
# bridge                  113
# bus                     113
# butterfly               146
# camel                   134
# can                     149
# castle                  133
# caterpillar             125
# cattle                  127
# chair                   121
# chimpanzee              139
# clock                   112
# cloud                   114
# cockroach               147
# couch                   104
# crab                    135
# crocodile               129
# cup                     129
# dinosaur                103
# dolphin                 108
# elephant                107
# flatfish                120
# forest                  107
# fox                     110
# girl                    101
# hamster                 115
# house                   101
# kangaroo                140
# keyboard                130
# lamp                    121
# lawn_mower              132
# leopard                 131
# lion                    130
# lizard                  100
# lobster                 142
# man                     102
# maple_tree              136
# motorcycle              131
# mountain                127
# mouse                   115
# mushroom                146
# oak_tree                100
# orange                  127
# orchid                  120
# otter                   100
# palm_tree               131
# pear                    101
# pickup_truck            102
# pine_tree               121
# plain                   103
# plate                   148
# poppy                   124
# porcupine               112
# possum                  108
# rabbit                  103
# raccoon                 129
# ray                     115
# road                    125
# rocket                  113
# rose                    120
# sea                     115
# seal                    116
# shark                   100
# shrew                   136
# skunk                   125
# skyscraper              142
# snail                   144
# snake                   114
# spider                  128
# squirrel                105
# streetcar               100
# sunflower               137
# sweet_pepper            130
# table                   100
# tank                    124
# telephone               116
# television              117
# tiger                   134
# tractor                 111
# train                   109
# trout                   116
# tulip                   103
# turtle                  111
# wardrobe                100
# whale                   104
# willow_tree             156
# wolf                    133
# woman                   107
# worm                    108
# ============================
# TOTAL                 11999
#
# Words with descriptions: 100/100
