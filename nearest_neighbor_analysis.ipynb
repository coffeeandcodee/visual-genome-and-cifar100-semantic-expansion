# %%
# NOTE nearest neighbor analysis
# ============================================================================
# SUPERCLASS COHERENCE SCORING
# ============================================================================
# For each model:
#   - Get 5 nearest neighbors for each CIFAR-100 word
#   - Count how many neighbors are in the SAME superclass
#   - Score = total count across all 100 words
# Max possible score = 100 words × 5 neighbors = 500 (if all neighbors are siblings)

import torch
import numpy as np
import os
import glob
from lab6 import SkipGramModel, find_similar_words
import torchvision

# Load CIFAR-100 class names
cifar100 = torchvision.datasets.CIFAR100(root='./data', download=True)
cifar_words = set(cifar100.classes)

# Define superclass structure
superclasses = {
    'aquatic_mammals': ['beaver', 'dolphin', 'otter', 'seal', 'whale'],
    'fish': ['aquarium_fish', 'flatfish', 'ray', 'shark', 'trout'],
    'flowers': ['orchid', 'poppy', 'rose', 'sunflower', 'tulip'],
    'fruit_and_vegetables': ['apple', 'mushroom', 'orange', 'pear', 'pepper'],
    'household_electrical': ['clock', 'keyboard', 'lamp', 'telephone', 'television'],
    'household_furniture': ['bed', 'chair', 'couch', 'table', 'wardrobe'],
    'insects': ['bee', 'beetle', 'butterfly', 'caterpillar', 'cockroach'],
    'large_carnivores': ['bear', 'leopard', 'lion', 'tiger', 'wolf'],
    'large_outdoor_things': ['bridge', 'castle', 'house', 'road', 'skyscraper'],
    'natural_scenes': ['cloud', 'forest', 'mountain', 'plain', 'sea'],
    'large_omnivores_herbivores': ['camel', 'cattle', 'chimpanzee', 'elephant', 'kangaroo'],
    'medium_mammals': ['fox', 'porcupine', 'possum', 'raccoon', 'skunk'],
    'invertebrates': ['crab', 'lobster', 'snail', 'spider', 'worm'],
    'people': ['baby', 'boy', 'girl', 'man', 'woman'],
    'reptiles': ['crocodile', 'dinosaur', 'lizard', 'snake', 'turtle'],
    'small_mammals': ['hamster', 'mouse', 'rabbit', 'shrew', 'squirrel'],
    'trees': ['maple', 'oak', 'palm', 'pine', 'willow'],
    'vehicles_1': ['bicycle', 'bus', 'motorcycle', 'pickup', 'train'],
    'vehicles_2': ['lawn_mower', 'rocket', 'streetcar', 'tank', 'tractor'],
}

# Build reverse lookup: word -> set of siblings (same superclass, excluding self)
word_to_siblings = {}
for superclass, words in superclasses.items():
    for word in words:
        word_to_siblings[word] = set(words) - {word}

# Find all model files
model_files = sorted(glob.glob('EMB*.pth'))
print(f"Found {len(model_files)} models to evaluate")
print("=" * 80)

# Score each model
results = []

for model_path in model_files:
    print(f"\nEvaluating: {model_path}")
    
    # Load model
    checkpoint = torch.load(model_path)
    nodes = checkpoint['nodes']
    embedding_dim = checkpoint['embedding_dim']
    vocab_size = checkpoint['vocab_size']
    
    model = SkipGramModel(vocab_size, embedding_dim)
    model.load_state_dict(checkpoint['model_state_dict'])
    embeddings = model.get_embeddings()
    
    node_set = set(nodes)
    
    # Score: count neighbors in same superclass
    total_score = 0
    words_evaluated = 0
    
    for word in cifar_words:
        if word not in node_set:
            continue
        
        words_evaluated += 1
        neighbors = find_similar_words(word, nodes, embeddings, top_k=5)
        neighbor_words = set([w for w, s in neighbors])
        
        # Count how many neighbors are siblings (same superclass)
        siblings = word_to_siblings.get(word, set())
        sibling_neighbors = neighbor_words & siblings
        total_score += len(sibling_neighbors)
    
    # Calculate percentage (max = 5 neighbors × 100 words = 500)
    max_possible = words_evaluated * 5
    percentage = (total_score / max_possible * 100) if max_possible > 0 else 0
    
    results.append({
        'model': model_path,
        'score': total_score,
        'max_possible': max_possible,
        'percentage': percentage,
        'embedding_dim': embedding_dim,
    })
    
    print(f"  Score: {total_score}/{max_possible} ({percentage:.1f}%)")

print("\n" + "=" * 80)
print("EVALUATION COMPLETE")
print("=" * 80)
# Out:
# Found 14 models to evaluate
# ================================================================================
#
# Evaluating: EMB128_NG10_CS2_BS64.pth
#   Score: 78/500 (15.6%)
#
# Evaluating: EMB256_NG10_CS2_BS64.pth
#   Score: 80/500 (16.0%)
#
# Evaluating: EMB32_NG10_CS2_BS64.pth
#   Score: 96/500 (19.2%)
#
# Evaluating: EMB64_NG10_CS1_BS64.pth
#   Score: 30/500 (6.0%)
#
# Evaluating: EMB64_NG10_CS2_BS128.pth
#   Score: 82/500 (16.4%)
#
# Evaluating: EMB64_NG10_CS2_BS256.pth
#   Score: 46/500 (9.2%)
#
# Evaluating: EMB64_NG10_CS2_BS32.pth
#   Score: 71/500 (14.2%)
#
# Evaluating: EMB64_NG10_CS2_BS64.pth
#   Score: 90/500 (18.0%)
#
# Evaluating: EMB64_NG10_CS3_BS64.pth
#   Score: 80/500 (16.0%)
#
# Evaluating: EMB64_NG10_CS4_BS64.pth
#   Score: 78/500 (15.6%)
#
# Evaluating: EMB64_NG15_CS2_BS64.pth
#   Score: 91/500 (18.2%)
#
# Evaluating: EMB64_NG20_CS2_BS64.pth
#   Score: 89/500 (17.8%)
#
# Evaluating: EMB64_NG20_CS3_BS32.pth
#   Score: 93/500 (18.6%)
#
# Evaluating: EMB64_NG5_CS2_BS64.pth
#   Score: 67/500 (13.4%)
#
# ================================================================================
# EVALUATION COMPLETE
# ================================================================================

# %%
# ============================================================================
# DISPLAY RANKINGS
# ============================================================================

import pandas as pd

# Sort by score (descending)
results_sorted = sorted(results, key=lambda x: x['score'], reverse=True)

print("=" * 80)
print("FINAL RANKINGS (by Superclass Coherence Score)")
print("=" * 80)
print(f"\n{'Rank':<6} {'Model':<35} {'Score':>8} {'Max':>6} {'%':>8}")
print("-" * 70)

for i, r in enumerate(results_sorted, 1):
    print(f"{i:<6} {r['model']:<35} {r['score']:>8} {r['max_possible']:>6} {r['percentage']:>7.1f}%")

# Highlight the winner
winner = results_sorted[0]
print(f"\n{'=' * 80}")
print(f"🏆 BEST MODEL: {winner['model']}")
print(f"   Score: {winner['score']}/{winner['max_possible']} ({winner['percentage']:.1f}% of neighbors are superclass siblings)")
print(f"{'=' * 80}")
# Out:
# ================================================================================
# FINAL RANKINGS (by Superclass Coherence Score)
# ================================================================================
#
# Rank   Model                                  Score    Max        %
# ----------------------------------------------------------------------
# 1      EMB32_NG10_CS2_BS64.pth                   96    500    19.2%
# 2      EMB64_NG20_CS3_BS32.pth                   93    500    18.6%
# 3      EMB64_NG15_CS2_BS64.pth                   91    500    18.2%
# 4      EMB64_NG10_CS2_BS64.pth                   90    500    18.0%
# 5      EMB64_NG20_CS2_BS64.pth                   89    500    17.8%
# 6      EMB64_NG10_CS2_BS128.pth                  82    500    16.4%
# 7      EMB256_NG10_CS2_BS64.pth                  80    500    16.0%
# 8      EMB64_NG10_CS3_BS64.pth                   80    500    16.0%
# 9      EMB128_NG10_CS2_BS64.pth                  78    500    15.6%
# 10     EMB64_NG10_CS4_BS64.pth                   78    500    15.6%
# 11     EMB64_NG10_CS2_BS32.pth                   71    500    14.2%
# 12     EMB64_NG5_CS2_BS64.pth                    67    500    13.4%
# 13     EMB64_NG10_CS2_BS256.pth                  46    500     9.2%
# 14     EMB64_NG10_CS1_BS64.pth                   30    500     6.0%
#
# ================================================================================
# 🏆 BEST MODEL: EMB32_NG10_CS2_BS64.pth
#    Score: 96/500 (19.2% of neighbors are superclass siblings)
# ================================================================================

# %%
# ============================================================================
# SAVE RESULTS TO CSV
# ============================================================================

df = pd.DataFrame(results_sorted)
df['rank'] = range(1, len(df) + 1)
df = df[['rank', 'model', 'score', 'max_possible', 'percentage', 'embedding_dim']]

csv_path = 'superclass_coherence_scores.csv'
df.to_csv(csv_path, index=False)
print(f"✅ Results saved to {csv_path}")
print("\n")
print(df.to_string(index=False))
# Out:
# ✅ Results saved to superclass_coherence_scores.csv
#
#
#  rank                    model  score  max_possible  percentage  embedding_dim
#     1  EMB32_NG10_CS2_BS64.pth     96           500        19.2             32
#     2  EMB64_NG20_CS3_BS32.pth     93           500        18.6             64
#     3  EMB64_NG15_CS2_BS64.pth     91           500        18.2             64
#     4  EMB64_NG10_CS2_BS64.pth     90           500        18.0             64
#     5  EMB64_NG20_CS2_BS64.pth     89           500        17.8             64
#     6 EMB64_NG10_CS2_BS128.pth     82           500        16.4             64
#     7 EMB256_NG10_CS2_BS64.pth     80           500        16.0            256
#     8  EMB64_NG10_CS3_BS64.pth     80           500        16.0             64
#     9 EMB128_NG10_CS2_BS64.pth     78           500        15.6            128
#    10  EMB64_NG10_CS4_BS64.pth     78           500        15.6             64
#    11  EMB64_NG10_CS2_BS32.pth     71           500        14.2             64
#    12   EMB64_NG5_CS2_BS64.pth     67           500        13.4             64
#    13 EMB64_NG10_CS2_BS256.pth     46           500         9.2             64
#    14  EMB64_NG10_CS1_BS64.pth     30           500         6.0             64

# %%
# NEAREST NEIGHBORS FOR BEST MODEL - CIFAR100 words
# ============================================================================
# Show 5 nearest neighbors for ALL 100 CIFAR-100 words
# ============================================================================

# Use the best model from rankings (or change this to analyze a different model)
MODEL_TO_ANALYZE = winner['model']  # Best model from previous cell

print(f"Loading model: {MODEL_TO_ANALYZE}")
checkpoint = torch.load(MODEL_TO_ANALYZE)
nodes = checkpoint['nodes']
embedding_dim = checkpoint['embedding_dim']
vocab_size = checkpoint['vocab_size']

model = SkipGramModel(vocab_size, embedding_dim)
model.load_state_dict(checkpoint['model_state_dict'])
embeddings = model.get_embeddings()
node_set = set(nodes)

print("=" * 100)
print(f"NEAREST NEIGHBORS FOR ALL CIFAR-100 WORDS ({MODEL_TO_ANALYZE})")
print("=" * 100)

# Sort CIFAR words alphabetically
cifar_words_sorted = sorted(cifar_words)

for word in cifar_words_sorted:
    if word in node_set:
        neighbors = find_similar_words(word, nodes, embeddings, top_k=5)
        neighbor_str = ", ".join([f"{w} ({s:.3f})" for w, s in neighbors])
        print(f"{word:<20} → {neighbor_str}")
    else:
        print(f"{word:<20} → ❌ NOT IN VOCABULARY")

print(f"\n✅ Displayed neighbors for {len([w for w in cifar_words_sorted if w in node_set])}/100 CIFAR-100 words")
# Out:
# Loading model: EMB32_NG10_CS2_BS64.pth
# ====================================================================================================
# NEAREST NEIGHBORS FOR ALL CIFAR-100 WORDS (EMB32_NG10_CS2_BS64.pth)
# ====================================================================================================
# apple                → open (0.927), field (0.905), vase (0.903), slice (0.900), pot (0.900)
# aquarium_fish        → trout (0.941), flatfish (0.920), spider (0.888), snake (0.870), skis (0.863)
# baby                 → eyes (0.960), little (0.945), colored (0.942), head (0.942), young (0.938)
# bear                 → clouds (0.876), elephant (0.846), mouse (0.844), very (0.841), dirt (0.841)
# beaver               → skunk (0.954), possum (0.951), crocodile (0.945), raccoon (0.943), otter (0.941)
# bed                  → front (0.903), holding (0.884), right (0.879), full (0.875), for (0.873)
# bee                  → rabbit (0.918), caterpillar (0.914), lion (0.908), spider (0.908), frisbee (0.903)
# beetle               → caterpillar (0.936), cockroach (0.929), worm (0.924), spider (0.909), snail (0.898)
# bicycle              → spoon (0.957), writing (0.944), giraffes (0.937), glasses (0.935), bananas (0.932)
# bottle               → surfer (0.909), jet (0.891), pile (0.885), collar (0.883), stove (0.883)
# bowl                 → cheese (0.906), box (0.887), donut (0.875), chair (0.872), container (0.871)
# boy                  → dog (0.880), surfboard (0.857), glove (0.856), shirt (0.847), game (0.841)
# bridge               → sky (0.945), hill (0.931), roof (0.927), lines (0.911), line (0.909)
# bus                  → writing (0.929), shoe (0.923), lettering (0.922), railing (0.918), letters (0.917)
# butterfly            → lizard (0.918), lettering (0.883), worm (0.878), cockroach (0.868), caterpillar (0.868)
# camel                → wolf (0.943), lion (0.939), squirrel (0.936), kangaroo (0.936), tiger (0.923)
# can                  → word (0.919), down (0.914), small (0.907), wet (0.895), for (0.894)
# castle               → skyscraper (0.945), forest (0.883), wardrobe (0.874), pavement (0.865), telephone (0.859)
# caterpillar          → spider (0.938), beetle (0.936), bee (0.914), worm (0.911), lizard (0.911)
# cattle               → lion (0.907), people (0.907), men (0.893), zebras (0.890), glasses (0.884)
# chair                → ceiling (0.934), piece (0.899), mirror (0.898), bathroom (0.897), box (0.893)
# chimpanzee           → leopard (0.922), wolf (0.919), possum (0.906), porcupine (0.906), kangaroo (0.902)
# clock                → wall (0.939), square (0.910), table (0.906), no (0.893), street (0.891)
# cloud                → mountains (0.926), horses (0.918), broccoli (0.910), cover (0.901), rocks (0.897)
# cockroach            → beetle (0.929), snail (0.921), spider (0.908), worm (0.908), caterpillar (0.878)
# couch                → sidewalk (0.958), skateboard (0.952), shorts (0.950), elephants (0.938), keyboard (0.935)
# crab                 → lobster (0.955), whale (0.896), shark (0.892), turtle (0.891), spider (0.865)
# crocodile            → beaver (0.945), whale (0.928), possum (0.928), otter (0.923), skunk (0.922)
# cup                  → closed (0.947), bush (0.906), vase (0.897), sink (0.872), wine (0.871)
# dinosaur             → wolf (0.918), fox (0.915), lion (0.895), rabbit (0.892), person's (0.890)
# dolphin              → whale (0.938), shark (0.899), tiger (0.896), dinosaur (0.880), people (0.872)
# elephant             → flag (0.880), horses (0.867), grass (0.852), horse (0.850), bear (0.846)
# flatfish             → trout (0.959), spider (0.935), snake (0.922), aquarium_fish (0.920), crocodile (0.910)
# forest               → castle (0.883), hydrant (0.877), ray (0.877), skyscraper (0.863), sea (0.863)
# fox                  → wolf (0.967), rabbit (0.941), lion (0.941), leopard (0.938), giraffe (0.933)
# girl                 → smiling (0.874), stuffed (0.870), an (0.867), ear (0.859), little (0.854)
# hamster              → skis (0.915), spider (0.902), trout (0.896), frisbee (0.894), fox (0.891)
# house                → trees (0.905), door (0.902), distance (0.901), covered (0.899), surface (0.897)
# kangaroo             → tiger (0.941), wolf (0.939), lion (0.939), camel (0.936), porcupine (0.922)
# keyboard             → shorts (0.957), elephants (0.950), sidewalk (0.947), couch (0.935), skateboard (0.931)
# lamp                 → box (0.901), glass (0.899), corner (0.895), screen (0.873), background (0.871)
# lawn_mower           → pickup_truck (0.935), tractor (0.933), streetcar (0.864), rocket (0.854), spoon (0.830)
# leopard              → tiger (0.938), fox (0.938), wolf (0.936), chimpanzee (0.922), lion (0.912)
# lion                 → wolf (0.961), giraffe (0.951), fox (0.941), camel (0.939), tiger (0.939)
# lizard               → snake (0.953), spider (0.940), shark (0.936), worm (0.919), butterfly (0.918)
# lobster              → crab (0.955), shark (0.894), lid (0.872), snake (0.866), whale (0.860)
# man                  → woman (0.880), skier (0.874), tennis (0.863), tie (0.854), man's (0.849)
# maple_tree           → palm_tree (0.949), willow_tree (0.943), oak_tree (0.935), pine_tree (0.901), stove (0.862)
# motorcycle           → tennis (0.893), truck (0.879), plane (0.876), suitcase (0.870), vehicle (0.860)
# mountain             → there (0.898), are (0.895), dark (0.882), above (0.876), face (0.876)
# mouse                → very (0.899), ball (0.885), sleeve (0.855), bear (0.844), curtain (0.834)
# mushroom             → pear (0.932), sunflower (0.920), tulip (0.881), orchid (0.868), banana (0.858)
# oak_tree             → willow_tree (0.970), pine_tree (0.967), palm_tree (0.967), maple_tree (0.935), hydrant (0.842)
# orange               → red (0.976), blue (0.974), small (0.966), colored (0.964), brown (0.963)
# orchid               → poppy (0.942), pear (0.937), sunflower (0.932), tulip (0.916), rose (0.877)
# otter                → beaver (0.941), possum (0.935), skunk (0.932), shrew (0.924), crocodile (0.923)
# palm_tree            → oak_tree (0.967), willow_tree (0.965), maple_tree (0.949), pine_tree (0.943), stove (0.850)
# pear                 → tulip (0.960), orchid (0.937), mushroom (0.932), sunflower (0.917), poppy (0.916)
# pickup_truck         → tractor (0.945), lawn_mower (0.935), rocket (0.924), streetcar (0.890), bananas (0.842)
# pine_tree            → oak_tree (0.967), willow_tree (0.959), palm_tree (0.943), maple_tree (0.901), hydrant (0.844)
# plain                → traffic (0.882), trash (0.864), ray (0.854), he (0.849), double (0.845)
# plate                → skateboard (0.918), donut (0.901), pizza (0.898), coffee (0.896), person (0.895)
# poppy                → tulip (0.949), orchid (0.942), pear (0.916), sunflower (0.902), rose (0.868)
# porcupine            → possum (0.962), raccoon (0.958), shrew (0.942), skunk (0.940), wolf (0.935)
# possum               → porcupine (0.962), raccoon (0.961), beaver (0.951), skunk (0.947), shrew (0.945)
# rabbit               → fox (0.941), wolf (0.933), seal (0.920), bee (0.918), lion (0.918)
# raccoon              → possum (0.961), porcupine (0.958), shrew (0.951), squirrel (0.945), beaver (0.943)
# ray                  → sea (0.887), forest (0.877), plain (0.854), traffic (0.848), castle (0.845)
# road                 → sun (0.916), area (0.907), mirror (0.897), dirt (0.892), window (0.885)
# rocket               → pickup_truck (0.924), tractor (0.912), lawn_mower (0.854), streetcar (0.851), telephone (0.826)
# rose                 → tulip (0.915), pear (0.889), orchid (0.877), sunflower (0.873), poppy (0.868)
# sea                  → ray (0.887), stove (0.870), forest (0.863), traffic (0.853), hydrant (0.853)
# seal                 → turtle (0.943), whale (0.925), rabbit (0.920), wolf (0.905), spider (0.905)
# shark                → lizard (0.936), whale (0.933), snake (0.930), dolphin (0.899), seal (0.899)
# shrew                → raccoon (0.951), possum (0.945), porcupine (0.942), beaver (0.928), fox (0.924)
# skunk                → beaver (0.954), possum (0.947), porcupine (0.940), raccoon (0.932), otter (0.932)
# skyscraper           → castle (0.945), telephone (0.865), forest (0.863), hydrant (0.856), bananas (0.854)
# snail                → cockroach (0.921), worm (0.915), spider (0.908), beetle (0.898), trout (0.896)
# snake                → lizard (0.953), shark (0.930), spider (0.926), whale (0.924), flatfish (0.922)
# spider               → trout (0.942), lizard (0.940), caterpillar (0.938), flatfish (0.935), worm (0.933)
# squirrel             → raccoon (0.945), camel (0.936), lion (0.935), porcupine (0.927), possum (0.923)
# streetcar            → pickup_truck (0.890), tractor (0.877), lawn_mower (0.864), rocket (0.851), snail (0.835)
# sunflower            → orchid (0.932), mushroom (0.920), pear (0.917), tulip (0.915), poppy (0.902)
# sweet_pepper         → pear (0.880), tulip (0.851), poppy (0.848), orchid (0.833), sunflower (0.827)
# table                → ceiling (0.926), wall (0.915), kitchen (0.913), clock (0.906), corner (0.901)
# tank                 → surfer (0.863), surfboard (0.862), flying (0.834), mouth (0.829), eye (0.813)
# telephone            → television (0.967), wardrobe (0.912), cell (0.865), skyscraper (0.865), castle (0.859)
# television           → telephone (0.967), wardrobe (0.915), castle (0.857), lid (0.849), double (0.843)
# tiger                → wolf (0.943), kangaroo (0.941), lion (0.939), leopard (0.938), camel (0.923)
# tractor              → pickup_truck (0.945), lawn_mower (0.933), rocket (0.912), streetcar (0.877), giraffes (0.847)
# train                → flag (0.911), area (0.910), set (0.897), concrete (0.892), window (0.891)
# trout                → flatfish (0.959), spider (0.942), aquarium_fish (0.941), snake (0.910), lizard (0.910)
# tulip                → pear (0.960), poppy (0.949), orchid (0.916), sunflower (0.915), rose (0.915)
# turtle               → seal (0.943), whale (0.925), crab (0.891), shark (0.887), rabbit (0.881)
# wardrobe             → television (0.915), telephone (0.912), spoon (0.883), lid (0.878), castle (0.874)
# whale                → dolphin (0.938), spider (0.933), shark (0.933), crocodile (0.928), seal (0.925)
# willow_tree          → oak_tree (0.970), palm_tree (0.965), pine_tree (0.959), maple_tree (0.943), hydrant (0.848)
# wolf                 → fox (0.967), lion (0.961), giraffe (0.944), camel (0.943), tiger (0.943)
# woman                → elephants (0.888), man (0.880), keyboard (0.876), shorts (0.870), broccoli (0.858)
# worm                 → spider (0.933), beetle (0.924), lizard (0.919), snail (0.915), caterpillar (0.911)
#
# ✅ Displayed neighbors for 100/100 CIFAR-100 words

# %%
# NEAREST NEIGHBORS FOR BEST MODEL - REMAINING VG WORDS (non-CIFAR)
# ============================================================================
# Show 5 nearest neighbors for all ~455 Visual Genome words NOT in CIFAR-100
# ============================================================================

# Get all words that are NOT in CIFAR-100
vg_only_words = sorted([w for w in nodes if w not in cifar_words])

print("=" * 100)
print(f"NEAREST NEIGHBORS FOR REMAINING {len(vg_only_words)} VG WORDS ({MODEL_TO_ANALYZE})")
print("=" * 100)

for word in vg_only_words:
    neighbors = find_similar_words(word, nodes, embeddings, top_k=5)
    neighbor_str = ", ".join([f"{w} ({s:.3f})" for w, s in neighbors])
    print(f"{word:<20} → {neighbor_str}")

print(f"\n✅ Displayed neighbors for {len(vg_only_words)} Visual Genome words (non-CIFAR)")
# Out:
# ====================================================================================================
# NEAREST NEIGHBORS FOR REMAINING 423 VG WORDS (EMB32_NG10_CS2_BS64.pth)
# ====================================================================================================
# a                    → is (0.986), in (0.978), of (0.978), the (0.968), and (0.967)
# above                → by (0.911), behind (0.909), over (0.902), scene (0.901), around (0.900)
# against              → big (0.983), from (0.983), through (0.981), at (0.976), has (0.973)
# air                  → rock (0.895), distance (0.894), house (0.888), view (0.873), door (0.866)
# airplane             → wire (0.895), tray (0.892), tennis (0.892), middle (0.883), his (0.872)
# along                → waves (0.906), ocean (0.901), boat (0.892), beach (0.886), pair (0.881)
# an                   → sitting (0.962), brown (0.950), black (0.946), has (0.936), from (0.936)
# and                  → is (0.973), in (0.972), big (0.967), a (0.967), to (0.966)
# animal               → ears (0.933), coat (0.923), ear (0.916), fur (0.898), walking (0.891)
# are                  → in (0.968), brown (0.968), around (0.967), has (0.964), and (0.964)
# area                 → train (0.910), clear (0.908), road (0.907), window (0.887), broccoli (0.884)
# arm                  → license (0.884), tire (0.879), flag (0.876), airplane (0.865), stop (0.861)
# around               → big (0.984), colorful (0.977), old (0.976), by (0.973), through (0.973)
# at                   → big (0.980), through (0.978), from (0.977), against (0.976), to (0.976)
# attached             → over (0.923), behind (0.913), wooden (0.910), stand (0.903), next (0.898)
# back                 → holding (0.964), looking (0.957), playing (0.956), sitting (0.953), watching (0.952)
# background           → corner (0.926), clear (0.918), glass (0.901), cover (0.899), three (0.898)
# backpack             → frisbee (0.952), racket (0.948), cell (0.942), letter (0.942), van (0.940)
# bag                  → knife (0.932), pants (0.918), pile (0.893), double (0.883), zebras (0.877)
# ball                 → sleeve (0.904), hands (0.892), mouse (0.885), rear (0.879), ears (0.871)
# banana               → pile (0.938), zebras (0.937), hydrant (0.936), bananas (0.924), oven (0.923)
# bananas              → spoon (0.973), writing (0.959), tv (0.949), pile (0.941), laptop (0.941)
# base                 → sky (0.922), tall (0.920), hill (0.917), trunk (0.915), top (0.913)
# baseball             → letter (0.934), racket (0.929), person's (0.927), zebras (0.924), lettering (0.923)
# basket               → fruit (0.943), flower (0.906), slice (0.903), patch (0.899), leaf (0.891)
# bat                  → racket (0.939), collar (0.929), taken (0.924), sunglasses (0.919), shoe (0.915)
# bathroom             → pole (0.926), keyboard (0.915), buildings (0.908), desk (0.904), lot (0.903)
# beach                → rock (0.913), ocean (0.909), wave (0.904), along (0.886), dish (0.886)
# behind               → under (0.966), old (0.959), by (0.957), covered (0.956), through (0.954)
# beige                → worn (0.912), corner (0.899), glass (0.886), empty (0.885), tower (0.884)
# being                → that (0.922), blue (0.900), white (0.899), bright (0.896), this (0.895)
# bench                → branch (0.913), sky (0.907), leaf (0.905), flowers (0.891), stand (0.886)
# beside               → near (0.942), green (0.930), over (0.927), off (0.922), behind (0.918)
# between              → over (0.939), around (0.936), near (0.922), off (0.921), face (0.919)
# big                  → around (0.984), colorful (0.983), against (0.983), old (0.982), at (0.980)
# bike                 → plane (0.922), mirror (0.902), tennis (0.894), sidewalk (0.889), donut (0.888)
# bird                 → rocks (0.895), broccoli (0.880), player (0.876), horse (0.875), donut (0.875)
# black                → brown (0.975), colored (0.972), red (0.970), blue (0.964), has (0.964)
# blanket              → spot (0.912), stand (0.851), green (0.843), beside (0.840), ground (0.832)
# blonde               → court (0.932), racket (0.927), collar (0.925), shoe (0.918), trash (0.917)
# blue                 → yellow (0.976), orange (0.974), red (0.973), white (0.967), pink (0.966)
# board                → glasses (0.952), giraffes (0.949), tv (0.946), racket (0.945), lettering (0.944)
# boat                 → sandwich (0.903), ocean (0.903), along (0.892), dish (0.863), waves (0.861)
# body                 → back (0.943), playing (0.933), flying (0.932), tail (0.931), many (0.927)
# book                 → screen (0.891), teddy (0.870), cup (0.867), wooden (0.864), box (0.854)
# bottom               → skiing (0.867), other (0.855), full (0.846), horses (0.846), cloudy (0.837)
# box                  → closed (0.924), lamp (0.901), glass (0.900), ceiling (0.900), chair (0.893)
# branch               → trunk (0.935), hill (0.928), fence (0.926), sky (0.914), bench (0.913)
# branches             → tree (0.908), branch (0.882), flowers (0.881), base (0.879), leaf (0.878)
# bread                → cheese (0.928), pizza (0.918), sandwich (0.908), field (0.900), apple (0.877)
# brick                → platform (0.970), passenger (0.961), windows (0.935), pole (0.932), windshield (0.927)
# bright               → sitting (0.969), colored (0.953), brown (0.953), black (0.951), for (0.950)
# broccoli             → rocks (0.937), buildings (0.935), clear (0.927), donut (0.926), keyboard (0.917)
# brown                → has (0.981), colored (0.976), black (0.975), in (0.974), from (0.973)
# building             → sun (0.914), full (0.889), clear (0.888), broccoli (0.874), road (0.867)
# buildings            → parking (0.941), broccoli (0.935), windows (0.932), lines (0.932), square (0.931)
# bunch                → field (0.914), flower (0.904), vase (0.892), plant (0.881), patch (0.879)
# bush                 → closed (0.943), vase (0.931), cup (0.906), bushes (0.905), field (0.887)
# bushes               → wine (0.932), bush (0.905), towel (0.895), closed (0.889), vase (0.862)
# button               → piece (0.920), cabinet (0.919), remote (0.905), screen (0.904), desk (0.901)
# by                   → old (0.988), big (0.977), has (0.975), through (0.974), colorful (0.974)
# cabinet              → rack (0.945), desk (0.933), button (0.919), shelf (0.913), tray (0.912)
# cake                 → made (0.914), dish (0.909), open (0.888), purple (0.887), distance (0.877)
# camera               → screen (0.909), desk (0.908), tennis (0.907), remote (0.906), cabinet (0.901)
# cap                  → short (0.901), container (0.894), cheese (0.870), pile (0.860), bread (0.850)
# car                  → counter (0.853), plastic (0.843), wing (0.839), t (0.838), clock (0.834)
# carrying             → holding (0.905), playing (0.904), riding (0.897), grey (0.892), blue (0.890)
# cars                 → double (0.952), cell (0.937), chain (0.931), taken (0.931), shoe (0.929)
# cat                  → airplane (0.863), snow (0.849), child (0.830), woman's (0.820), curtain (0.813)
# ceiling              → corner (0.945), glass (0.939), chair (0.934), mirror (0.932), table (0.926)
# cell                 → giraffes (0.953), racket (0.951), chain (0.950), railing (0.950), letter (0.949)
# cement               → metal (0.899), silver (0.896), word (0.858), city (0.849), empty (0.841)
# chain                → cell (0.950), shoe (0.945), taken (0.944), letter (0.933), cars (0.931)
# cheese               → bread (0.928), piece (0.920), bowl (0.906), container (0.901), pizza (0.901)
# child                → snow (0.897), sleeve (0.892), bright (0.879), photo (0.877), hand (0.877)
# city                 → word (0.883), floor (0.870), flag (0.860), wet (0.859), outside (0.856)
# clear                → concrete (0.935), glass (0.928), broccoli (0.927), corner (0.919), buildings (0.918)
# closed               → cup (0.947), vase (0.943), bush (0.943), box (0.924), field (0.905)
# cloth                → lid (0.929), writing (0.921), zebras (0.917), lettering (0.906), shoe (0.905)
# clouds               → windows (0.912), sidewalk (0.900), platform (0.896), brick (0.888), lines (0.885)
# cloudy               → cloud (0.883), other (0.879), horses (0.878), guy (0.858), skiing (0.840)
# coat                 → ears (0.959), fur (0.958), walking (0.943), tracks (0.936), ear (0.926)
# coffee               → lot (0.967), donut (0.948), skateboard (0.944), tile (0.944), sidewalk (0.938)
# collar               → shoe (0.961), tv (0.957), racket (0.953), court (0.948), suitcase (0.940)
# color                → brown (0.919), white (0.917), blue (0.917), that (0.916), red (0.914)
# colored              → brown (0.976), black (0.972), has (0.965), orange (0.964), this (0.963)
# colorful             → big (0.983), around (0.977), old (0.977), by (0.974), this (0.971)
# computer             → post (0.940), tray (0.928), railing (0.908), desk (0.903), cabinet (0.899)
# concrete             → clear (0.935), flag (0.922), four (0.921), middle (0.917), several (0.915)
# container            → cheese (0.901), cap (0.894), piece (0.880), bowl (0.871), rail (0.870)
# corner               → ceiling (0.945), glass (0.940), three (0.929), background (0.926), clear (0.919)
# counter              → pole (0.883), knife (0.882), oven (0.878), wall (0.874), signs (0.872)
# court                → shoe (0.949), collar (0.948), tv (0.948), suitcase (0.943), racket (0.934)
# cover                → rocks (0.908), clear (0.904), cloud (0.901), background (0.899), line (0.895)
# covered              → behind (0.956), under (0.939), through (0.935), old (0.932), by (0.931)
# cow                  → tag (0.896), dog (0.893), group (0.889), bottle (0.875), glove (0.847)
# cows                 → giraffes (0.948), sheep (0.944), tv (0.933), shoe (0.932), stove (0.930)
# curtain              → four (0.858), keyboard (0.858), screen (0.851), very (0.847), street (0.847)
# dark                 → grey (0.965), gray (0.965), face (0.963), has (0.963), brown (0.962)
# design               → red (0.924), painted (0.918), yellow (0.917), logo (0.916), blue (0.914)
# desk                 → remote (0.972), set (0.950), cabinet (0.933), tray (0.929), mirror (0.926)
# dirt                 → sun (0.900), road (0.892), full (0.885), area (0.877), grass (0.870)
# dish                 → cake (0.909), pizza (0.895), beach (0.886), paper (0.881), distance (0.879)
# display              → wooden (0.923), over (0.908), that (0.905), three (0.895), are (0.895)
# distance             → some (0.915), house (0.901), air (0.894), surface (0.893), over (0.891)
# dog                  → cow (0.893), ear (0.888), animal (0.887), wearing (0.882), boy (0.880)
# donut                → lot (0.958), coffee (0.948), broccoli (0.926), skateboard (0.924), keyboard (0.923)
# door                 → house (0.902), window (0.885), base (0.879), trees (0.878), fence (0.877)
# double               → cars (0.952), lid (0.947), zebras (0.946), cell (0.944), tv (0.943)
# down                 → side (0.945), word (0.928), gray (0.927), inside (0.917), can (0.914)
# dress                → piece (0.883), dish (0.877), cake (0.875), round (0.867), color (0.867)
# ear                  → watching (0.936), neck (0.933), nose (0.932), fur (0.930), coat (0.926)
# ears                 → coat (0.959), fur (0.935), animal (0.933), ear (0.916), hands (0.915)
# eating               → playing (0.964), back (0.944), tail (0.943), watching (0.942), little (0.936)
# edge                 → scene (0.901), base (0.898), tall (0.890), sky (0.885), cover (0.885)
# elephants            → shorts (0.958), keyboard (0.950), sidewalk (0.942), skateboard (0.938), couch (0.938)
# empty                → wall (0.902), sand (0.902), four (0.900), corner (0.900), shelf (0.897)
# end                  → parking (0.925), window (0.906), lines (0.904), wall (0.903), set (0.903)
# engine               → parked (0.939), seat (0.920), platform (0.901), stop (0.895), part (0.890)
# eye                  → flying (0.946), back (0.926), head (0.921), tail (0.914), statue (0.913)
# eyes                 → baby (0.960), head (0.959), little (0.955), playing (0.938), eating (0.932)
# face                 → has (0.979), big (0.971), by (0.970), old (0.970), colorful (0.970)
# feet                 → shadow (0.912), at (0.891), by (0.889), face (0.889), under (0.888)
# fence                → trunk (0.941), hill (0.936), branch (0.926), sky (0.903), base (0.895)
# field                → flower (0.919), bunch (0.914), apple (0.905), closed (0.905), vase (0.901)
# fire                 → covered (0.903), branches (0.873), to (0.853), at (0.846), feet (0.846)
# flag                 → concrete (0.922), train (0.911), these (0.905), middle (0.889), grass (0.881)
# floor                → wet (0.927), dark (0.916), reflection (0.910), under (0.909), near (0.903)
# flower               → flowers (0.947), leaf (0.940), vase (0.933), plant (0.931), patch (0.924)
# flowers              → leaf (0.968), flower (0.947), tree (0.938), leaves (0.935), tall (0.908)
# flying               → eye (0.946), back (0.941), body (0.932), eating (0.930), eyes (0.926)
# food                 → ears (0.905), animal (0.886), group (0.882), baby (0.869), tail (0.865)
# foot                 → tracks (0.900), tail (0.899), eating (0.893), suit (0.890), watching (0.890)
# for                  → has (0.979), with (0.979), by (0.972), big (0.971), this (0.970)
# fork                 → suitcase (0.882), donut (0.872), court (0.870), trash (0.869), lot (0.867)
# four                 → remote (0.924), concrete (0.921), plane (0.919), desk (0.916), clear (0.916)
# frame                → wheel (0.897), wooden (0.876), his (0.875), box (0.861), worn (0.861)
# frisbee              → backpack (0.952), sheep (0.947), racket (0.940), letter (0.938), lettering (0.937)
# from                 → has (0.983), against (0.983), this (0.979), big (0.979), at (0.977)
# front                → bed (0.903), ears (0.871), ball (0.870), snow (0.857), there (0.853)
# fruit                → basket (0.943), flower (0.918), leaf (0.910), tree (0.904), flowers (0.895)
# full                 → sun (0.901), building (0.889), dirt (0.885), bed (0.875), right (0.869)
# fur                  → nose (0.966), coat (0.958), walking (0.949), tail (0.943), ears (0.935)
# game                 → walking (0.896), nose (0.887), watching (0.877), tracks (0.865), playing (0.864)
# giraffe              → zebra (0.956), lion (0.951), wolf (0.944), possum (0.937), sunglasses (0.937)
# giraffes             → glasses (0.959), zebras (0.956), sheep (0.953), cell (0.953), board (0.949)
# glass                → corner (0.940), ceiling (0.939), three (0.931), clear (0.928), four (0.909)
# glasses              → giraffes (0.959), board (0.952), zebras (0.950), sunglasses (0.943), writing (0.940)
# glove                → dog (0.868), boy (0.856), he (0.854), racket (0.849), glasses (0.848)
# gold                 → blue (0.939), silver (0.933), yellow (0.929), inside (0.917), red (0.914)
# grass                → sand (0.898), flag (0.881), stone (0.877), concrete (0.873), dirt (0.870)
# gray                 → looking (0.968), grey (0.966), dark (0.965), has (0.955), for (0.953)
# green                → in (0.962), through (0.962), large (0.961), small (0.958), has (0.958)
# grey                 → gray (0.966), dark (0.965), by (0.958), for (0.951), has (0.950)
# ground               → wood (0.897), line (0.897), top (0.892), tall (0.887), sky (0.884)
# group                → ear (0.893), cow (0.889), food (0.882), ears (0.867), baby (0.863)
# growing              → young (0.881), stand (0.869), around (0.865), to (0.859), next (0.859)
# guy                  → sand (0.876), lot (0.866), cloudy (0.858), bird (0.858), t (0.850)
# hair                 → there (0.912), other (0.899), water (0.890), wet (0.883), skiing (0.875)
# hand                 → child (0.877), of (0.874), to (0.870), two (0.870), along (0.869)
# handle               → parked (0.913), section (0.907), stop (0.906), seat (0.902), windshield (0.878)
# hands                → ears (0.915), coat (0.905), ball (0.892), fur (0.892), ear (0.872)
# hanging              → stuffed (0.906), purple (0.905), leg (0.888), logo (0.888), an (0.884)
# has                  → from (0.983), brown (0.981), face (0.979), for (0.979), big (0.978)
# hat                  → statue (0.873), snow (0.854), tie (0.845), shirt (0.842), head (0.826)
# have                 → colored (0.909), dark (0.902), black (0.900), brown (0.898), gray (0.898)
# he                   → taken (0.935), glasses (0.916), lettering (0.914), chain (0.913), blonde (0.907)
# head                 → eyes (0.959), little (0.952), photo (0.948), bright (0.945), baby (0.942)
# helmet               → sidewalk (0.893), racket (0.880), seat (0.879), platform (0.877), clouds (0.869)
# her                  → design (0.899), sitting (0.894), an (0.887), black (0.878), brown (0.875)
# hill                 → sky (0.938), fence (0.936), bridge (0.931), branch (0.928), base (0.917)
# his                  → worn (0.921), wooden (0.918), blue (0.908), design (0.899), painted (0.898)
# holding              → back (0.964), gray (0.952), looking (0.948), sitting (0.948), white (0.944)
# horse                → toilet (0.948), horses (0.948), mountains (0.908), shoe (0.889), cloud (0.887)
# horses               → horse (0.948), skiing (0.929), cloud (0.918), mountains (0.909), toilet (0.906)
# hot                  → patch (0.887), pot (0.876), purple (0.874), vase (0.870), flower (0.861)
# hydrant              → stove (0.956), bananas (0.937), banana (0.936), sunglasses (0.932), railing (0.929)
# in                   → is (0.978), a (0.978), brown (0.974), of (0.972), and (0.972)
# inside               → yellow (0.941), blue (0.940), red (0.939), orange (0.931), made (0.929)
# into                 → near (0.954), through (0.949), colorful (0.947), around (0.947), under (0.946)
# is                   → a (0.986), on (0.979), in (0.978), of (0.976), and (0.973)
# it                   → blue (0.878), sign (0.875), pink (0.871), plastic (0.870), long (0.867)
# jacket               → suit (0.852), left (0.850), dog (0.848), fork (0.847), elephants (0.846)
# jeans                → shoe (0.936), giraffes (0.922), taken (0.919), zebras (0.918), jet (0.918)
# jet                  → shoe (0.940), letter (0.933), giraffes (0.928), cell (0.927), writing (0.927)
# kitchen              → table (0.913), button (0.891), phone (0.884), piece (0.875), wood (0.875)
# kite                 → leg (0.915), shirt (0.868), flying (0.865), statue (0.860), hanging (0.860)
# knife                → bag (0.932), pile (0.912), double (0.899), zebras (0.894), oven (0.892)
# lady                 → poles (0.898), number (0.868), phone (0.868), clock (0.863), short (0.861)
# laptop               → sheep (0.956), writing (0.953), spoon (0.943), board (0.943), cell (0.941)
# large                → has (0.976), through (0.975), against (0.972), big (0.971), from (0.967)
# laying               → white (0.884), holding (0.883), two (0.874), back (0.863), ear (0.862)
# leaf                 → flowers (0.968), flower (0.940), tree (0.940), fruit (0.910), bench (0.905)
# leaves               → flowers (0.935), stand (0.928), and (0.912), surface (0.900), green (0.900)
# left                 → right (0.910), his (0.888), suit (0.874), side (0.864), very (0.859)
# leg                  → kite (0.915), flying (0.912), statue (0.890), logo (0.888), hanging (0.888)
# legs                 → flying (0.917), stripes (0.913), body (0.911), stripe (0.899), eye (0.891)
# letter               → cell (0.949), shoe (0.946), backpack (0.942), suitcase (0.939), frisbee (0.938)
# lettering            → writing (0.953), lid (0.948), board (0.944), tv (0.939), cell (0.939)
# letters              → shoe (0.949), writing (0.944), cell (0.940), racket (0.937), railing (0.933)
# license              → tire (0.895), wheels (0.889), wheel (0.888), arm (0.884), handle (0.876)
# lid                  → zebras (0.951), lettering (0.948), double (0.947), tv (0.944), writing (0.942)
# light                → lights (0.930), inside (0.902), red (0.901), green (0.896), orange (0.889)
# lights               → light (0.930), inside (0.898), distance (0.889), side (0.880), over (0.877)
# line                 → wood (0.929), sky (0.922), roof (0.921), top (0.917), trunk (0.911)
# lines                → roof (0.939), parking (0.938), buildings (0.932), windows (0.922), wall (0.921)
# little               → looking (0.957), eyes (0.955), head (0.952), colored (0.949), baby (0.945)
# logo                 → design (0.916), an (0.903), black (0.903), painted (0.902), has (0.902)
# long                 → has (0.950), black (0.946), red (0.944), gray (0.943), brown (0.939)
# looking              → gray (0.968), little (0.957), back (0.957), colorful (0.954), colored (0.951)
# lot                  → coffee (0.967), donut (0.958), skateboard (0.946), sidewalk (0.930), elephants (0.927)
# luggage              → he (0.850), skis (0.841), taken (0.832), boy (0.830), glove (0.827)
# made                 → yellow (0.945), inside (0.929), purple (0.927), pink (0.927), orange (0.927)
# man's                → zebra (0.946), giraffe (0.929), racket (0.928), person's (0.920), zebras (0.920)
# many                 → body (0.927), back (0.913), striped (0.912), mouth (0.907), black (0.904)
# men                  → zebras (0.968), tv (0.953), writing (0.943), giraffes (0.940), racket (0.939)
# metal                → word (0.927), tan (0.921), silver (0.920), blue (0.903), cement (0.899)
# middle               → wire (0.935), tag (0.917), concrete (0.917), four (0.903), these (0.901)
# mirror               → window (0.933), ceiling (0.932), desk (0.926), wood (0.910), glass (0.908)
# monitor              → plastic (0.888), number (0.887), beige (0.840), clock (0.837), design (0.834)
# mountains            → cloud (0.926), clear (0.914), horses (0.909), horse (0.908), toilet (0.902)
# mouth                → playing (0.923), watching (0.917), tail (0.912), eye (0.912), eating (0.912)
# napkin               → suitcase (0.869), oven (0.858), teddy (0.856), letter (0.855), letters (0.851)
# near                 → old (0.961), by (0.956), colorful (0.955), into (0.954), under (0.952)
# neck                 → nose (0.949), fur (0.934), ear (0.933), tail (0.933), walking (0.928)
# next                 → stand (0.921), that (0.902), attached (0.898), open (0.893), green (0.883)
# no                   → some (0.901), clear (0.901), concrete (0.895), clock (0.893), glass (0.878)
# nose                 → fur (0.966), tail (0.960), neck (0.949), watching (0.939), ear (0.932)
# number               → monitor (0.887), poles (0.886), phone (0.877), beige (0.869), counter (0.868)
# numbers              → poles (0.925), phone (0.908), tennis (0.903), section (0.894), computer (0.891)
# ocean                → waves (0.941), beach (0.909), boat (0.903), along (0.901), rock (0.887)
# of                   → a (0.978), is (0.976), in (0.972), the (0.971), with (0.969)
# off                  → surface (0.939), stand (0.926), over (0.925), near (0.922), beside (0.922)
# old                  → by (0.988), big (0.982), colorful (0.977), through (0.976), around (0.976)
# on                   → is (0.979), the (0.967), of (0.966), a (0.965), in (0.955)
# one                  → small (0.947), under (0.942), red (0.940), for (0.940), has (0.939)
# open                 → apple (0.927), some (0.909), slice (0.908), leaf (0.901), stand (0.898)
# other                → there (0.905), hair (0.899), wet (0.882), cloudy (0.879), looking (0.872)
# out                  → through (0.950), standing (0.938), under (0.935), against (0.934), at (0.927)
# outside              → grey (0.944), white (0.943), blue (0.923), word (0.917), gray (0.915)
# oven                 → writing (0.940), railing (0.939), shoe (0.935), lettering (0.932), bananas (0.930)
# over                 → near (0.950), by (0.950), behind (0.948), old (0.947), around (0.946)
# painted              → brown (0.945), pink (0.943), small (0.941), red (0.938), blue (0.937)
# pair                 → along (0.881), beach (0.862), waves (0.860), ocean (0.854), other (0.838)
# pants                → bag (0.918), zebras (0.913), double (0.913), wrist (0.897), skier (0.897)
# paper                → gold (0.908), display (0.886), dish (0.881), purple (0.879), two (0.877)
# park                 → mountain (0.865), player (0.849), sleeve (0.849), curtain (0.846), scene (0.845)
# parked               → engine (0.939), handle (0.913), seat (0.905), stop (0.904), wheels (0.895)
# parking              → buildings (0.941), lines (0.938), end (0.925), windows (0.917), broccoli (0.911)
# part                 → window (0.897), four (0.890), engine (0.890), camera (0.871), piece (0.869)
# passenger            → brick (0.961), platform (0.951), windshield (0.937), pole (0.919), windows (0.906)
# patch                → flower (0.924), vase (0.909), plant (0.901), basket (0.899), slice (0.898)
# pavement             → suitcase (0.937), laptop (0.937), zebras (0.935), men (0.935), shoe (0.934)
# people               → zebras (0.948), giraffes (0.943), shoes (0.941), sheep (0.939), cell (0.937)
# person               → plate (0.895), skateboard (0.892), couch (0.889), player (0.867), shorts (0.863)
# person's             → racket (0.929), baseball (0.927), man's (0.920), ski (0.918), frisbee (0.911)
# phone                → poles (0.920), screen (0.919), numbers (0.908), kitchen (0.884), button (0.883)
# photo                → head (0.948), bright (0.947), sitting (0.920), colored (0.908), brown (0.897)
# picture              → long (0.903), black (0.896), red (0.895), gray (0.895), plastic (0.891)
# piece                → button (0.920), cheese (0.920), shelf (0.906), chair (0.899), tennis (0.894)
# pile                 → zebras (0.948), giraffes (0.943), bananas (0.941), banana (0.938), sunglasses (0.936)
# pillow               → towel (0.866), slice (0.864), bag (0.856), pants (0.839), knife (0.839)
# pink                 → yellow (0.970), blue (0.966), red (0.965), orange (0.960), small (0.953)
# pizza                → bread (0.918), cheese (0.901), plate (0.898), sandwich (0.897), dish (0.895)
# plane                → bike (0.922), four (0.919), tennis (0.904), ceiling (0.896), mirror (0.894)
# plant                → flower (0.931), patch (0.901), field (0.900), display (0.893), leaf (0.890)
# plastic              → white (0.907), blue (0.903), yellow (0.900), picture (0.891), monitor (0.888)
# platform             → brick (0.970), passenger (0.951), windshield (0.934), pole (0.922), stop (0.902)
# player               → sand (0.887), bird (0.876), tie (0.869), person (0.867), umbrella (0.862)
# playing              → watching (0.965), eating (0.964), tail (0.958), back (0.956), eyes (0.938)
# pole                 → brick (0.932), bathroom (0.926), platform (0.922), passenger (0.919), keyboard (0.899)
# poles                → numbers (0.925), phone (0.920), lady (0.898), post (0.890), tennis (0.889)
# post                 → computer (0.940), bathroom (0.902), shelf (0.895), poles (0.890), street (0.888)
# pot                  → vase (0.934), flower (0.909), apple (0.900), patch (0.896), slice (0.879)
# purple               → pink (0.942), made (0.927), yellow (0.927), red (0.908), gold (0.906)
# rack                 → cabinet (0.945), shelf (0.932), tennis (0.921), section (0.915), window (0.914)
# racket               → tv (0.963), zebras (0.957), shoe (0.956), van (0.953), collar (0.953)
# rail                 → section (0.944), tennis (0.927), rack (0.908), piece (0.882), cabinet (0.879)
# railing              → cell (0.950), writing (0.941), oven (0.939), bananas (0.939), shoe (0.938)
# rear                 → tracks (0.879), ball (0.879), ears (0.862), coat (0.861), bright (0.845)
# red                  → orange (0.976), blue (0.973), brown (0.973), black (0.970), yellow (0.967)
# reflection           → floor (0.910), wet (0.907), scene (0.902), under (0.901), above (0.885)
# remote               → desk (0.972), set (0.926), four (0.924), square (0.906), camera (0.906)
# riding               → gray (0.938), back (0.935), watching (0.934), eating (0.927), holding (0.918)
# right                → left (0.910), bed (0.879), full (0.869), of (0.860), metal (0.859)
# rock                 → beach (0.913), wave (0.909), stone (0.905), waves (0.896), air (0.895)
# rocks                → broccoli (0.937), cover (0.908), bridge (0.901), lines (0.897), cloud (0.897)
# roof                 → lines (0.939), bridge (0.927), line (0.921), top (0.897), mirror (0.896)
# room                 → shelf (0.884), window (0.883), sun (0.881), rack (0.879), four (0.865)
# round                → blue (0.922), yellow (0.911), made (0.909), white (0.904), orange (0.901)
# row                  → closed (0.897), box (0.886), bush (0.880), field (0.863), glass (0.846)
# sand                 → empty (0.902), grass (0.898), player (0.887), guy (0.876), rock (0.867)
# sandwich             → bread (0.908), sauce (0.905), boat (0.903), pizza (0.897), pot (0.878)
# sauce                → sandwich (0.905), bread (0.873), pizza (0.848), boat (0.841), pile (0.834)
# scene                → through (0.933), around (0.929), by (0.927), in (0.927), face (0.926)
# screen               → phone (0.919), tennis (0.910), camera (0.909), button (0.904), wall (0.900)
# seat                 → wheels (0.940), stop (0.926), engine (0.920), parked (0.905), handle (0.902)
# section              → rail (0.944), tennis (0.938), rack (0.915), handle (0.907), numbers (0.894)
# set                  → desk (0.950), window (0.927), remote (0.926), wall (0.914), concrete (0.907)
# several              → concrete (0.915), clear (0.893), worn (0.889), three (0.884), middle (0.883)
# shadow               → through (0.955), at (0.952), by (0.952), has (0.951), from (0.947)
# sheep                → laptop (0.956), giraffes (0.953), frisbee (0.947), zebras (0.946), cows (0.944)
# shelf                → rack (0.932), wood (0.918), cabinet (0.913), piece (0.906), button (0.898)
# shirt                → t (0.872), surfboard (0.869), statue (0.869), kite (0.868), eye (0.858)
# shoe                 → collar (0.961), writing (0.961), tv (0.958), racket (0.956), court (0.949)
# shoes                → zebras (0.946), people (0.941), glasses (0.931), giraffes (0.931), sheep (0.926)
# short                → cap (0.901), lady (0.861), knife (0.855), number (0.853), is (0.850)
# shorts               → elephants (0.958), keyboard (0.957), couch (0.950), sidewalk (0.943), skateboard (0.933)
# side                 → down (0.945), gray (0.943), near (0.936), under (0.931), by (0.929)
# sidewalk             → couch (0.958), keyboard (0.947), shorts (0.943), elephants (0.942), skateboard (0.939)
# sign                 → side (0.902), behind (0.899), gray (0.897), green (0.890), picture (0.887)
# signs                → windshield (0.946), wall (0.904), platform (0.902), worn (0.884), window (0.882)
# silver               → blue (0.933), gold (0.933), metal (0.920), yellow (0.913), word (0.908)
# sink                 → keyboard (0.911), donut (0.899), couch (0.893), table (0.886), lot (0.886)
# sitting              → bright (0.969), brown (0.966), an (0.962), colored (0.961), black (0.960)
# skateboard           → couch (0.952), lot (0.946), coffee (0.944), sidewalk (0.939), elephants (0.938)
# ski                  → cell (0.945), racket (0.938), letter (0.934), tv (0.933), shoe (0.926)
# skier                → sunglasses (0.935), racket (0.923), tv (0.923), glasses (0.921), wrist (0.920)
# skiing               → horses (0.929), there (0.885), hair (0.875), horse (0.868), bottom (0.867)
# skis                 → writing (0.941), frisbee (0.935), lettering (0.931), lid (0.927), glasses (0.924)
# sky                  → bridge (0.945), hill (0.938), top (0.928), line (0.922), base (0.922)
# sleeve               → ball (0.904), t (0.893), child (0.892), gray (0.881), floor (0.872)
# slice                → open (0.908), basket (0.903), apple (0.900), patch (0.898), purple (0.884)
# small                → brown (0.971), this (0.969), for (0.969), colorful (0.969), has (0.966)
# smiling              → back (0.946), little (0.935), head (0.930), holding (0.928), colored (0.924)
# snow                 → child (0.897), player (0.859), front (0.857), bed (0.855), hat (0.854)
# some                 → distance (0.915), open (0.909), no (0.901), near (0.900), beside (0.900)
# spoon                → bananas (0.973), bicycle (0.957), cell (0.947), laptop (0.943), writing (0.942)
# spot                 → blanket (0.912), at (0.878), and (0.869), against (0.869), to (0.867)
# square               → buildings (0.931), wall (0.924), clock (0.910), remote (0.906), parking (0.898)
# stand                → green (0.947), against (0.941), surface (0.936), behind (0.931), leaves (0.928)
# standing             → big (0.975), to (0.972), through (0.968), up (0.966), this (0.965)
# statue               → head (0.914), eye (0.913), stuffed (0.899), walking (0.898), baby (0.895)
# stone                → rock (0.905), word (0.882), concrete (0.880), down (0.880), grass (0.877)
# stop                 → seat (0.926), windshield (0.913), handle (0.906), parked (0.904), platform (0.902)
# stove                → hydrant (0.956), trash (0.935), bananas (0.932), cows (0.930), giraffes (0.928)
# street               → broccoli (0.911), clear (0.907), lot (0.894), buildings (0.891), clock (0.891)
# stripe               → stripes (0.923), legs (0.899), body (0.858), game (0.844), walking (0.839)
# striped              → red (0.941), yellow (0.938), blue (0.935), black (0.933), pink (0.933)
# stripes              → stripe (0.923), legs (0.913), walking (0.896), head (0.878), neck (0.871)
# stuffed              → little (0.934), sitting (0.930), eyes (0.926), baby (0.926), head (0.919)
# suit                 → holding (0.900), foot (0.890), dog (0.876), left (0.874), wearing (0.874)
# suitcase             → racket (0.949), writing (0.947), shoe (0.946), court (0.943), cell (0.941)
# sun                  → road (0.916), building (0.914), full (0.901), dirt (0.900), area (0.884)
# sunglasses           → giraffes (0.947), shoe (0.946), glasses (0.943), tv (0.942), zebras (0.940)
# surface              → off (0.939), stand (0.936), green (0.935), over (0.930), near (0.913)
# surfboard            → shirt (0.869), tank (0.862), boy (0.857), surfer (0.838), boat (0.824)
# surfer               → bus (0.909), bottle (0.909), jet (0.874), glasses (0.870), tank (0.863)
# sweater              → letter (0.936), shoe (0.924), frisbee (0.923), railing (0.922), lettering (0.921)
# t                    → sleeve (0.893), black (0.877), two (0.877), dark (0.876), brown (0.875)
# tag                  → middle (0.917), these (0.898), cow (0.896), two (0.877), there (0.872)
# tail                 → nose (0.960), playing (0.958), watching (0.953), eating (0.943), fur (0.943)
# taken                → van (0.956), zebras (0.946), shoe (0.944), racket (0.944), chain (0.944)
# tall                 → base (0.920), wooden (0.911), flowers (0.908), leaves (0.894), surface (0.892)
# tan                  → metal (0.921), word (0.912), back (0.902), dark (0.896), white (0.889)
# teddy                → towel (0.893), wine (0.892), book (0.870), napkin (0.856), bushes (0.853)
# tennis               → section (0.938), rail (0.927), rack (0.921), screen (0.910), camera (0.907)
# that                 → small (0.944), red (0.929), painted (0.928), colorful (0.924), pink (0.924)
# the                  → of (0.971), in (0.968), a (0.968), is (0.967), on (0.967)
# there                → hair (0.912), other (0.905), wet (0.899), mountain (0.898), water (0.888)
# these                → flag (0.905), middle (0.901), tag (0.898), concrete (0.875), train (0.871)
# this                 → from (0.979), has (0.975), big (0.972), brown (0.972), colorful (0.971)
# three                → glass (0.931), corner (0.929), ceiling (0.915), background (0.898), display (0.895)
# through              → against (0.981), big (0.978), at (0.978), has (0.977), old (0.976)
# tie                  → player (0.869), donut (0.864), lot (0.863), coffee (0.861), sand (0.861)
# tile                 → coffee (0.944), sidewalk (0.939), skateboard (0.932), elephants (0.932), keyboard (0.929)
# tire                 → license (0.895), wheel (0.887), arm (0.879), wheels (0.870), seat (0.866)
# to                   → big (0.978), at (0.976), through (0.973), around (0.973), standing (0.972)
# toilet               → horse (0.948), sidewalk (0.928), shoe (0.917), laptop (0.912), couch (0.907)
# top                  → wood (0.968), sky (0.928), line (0.917), base (0.913), hill (0.910)
# towel                → wine (0.947), bushes (0.895), teddy (0.893), wing (0.866), pillow (0.866)
# tower                → mirror (0.905), glass (0.904), end (0.901), set (0.897), top (0.893)
# track                → white (0.843), walking (0.837), blue (0.834), signs (0.832), gray (0.828)
# tracks               → coat (0.936), walking (0.929), fur (0.928), watching (0.910), tail (0.903)
# traffic              → chain (0.926), trash (0.918), spoon (0.908), shoe (0.907), cars (0.904)
# trash                → giraffes (0.943), spoon (0.936), taken (0.935), stove (0.935), shoe (0.933)
# tray                 → desk (0.929), computer (0.928), cabinet (0.912), remote (0.905), airplane (0.892)
# tree                 → leaf (0.940), flowers (0.938), flower (0.912), branches (0.908), fruit (0.904)
# trees                → house (0.905), hill (0.897), sky (0.895), branch (0.887), tree (0.887)
# truck                → parked (0.893), motorcycle (0.879), license (0.873), wheel (0.866), part (0.863)
# trunk                → fence (0.941), branch (0.935), hill (0.916), base (0.915), line (0.911)
# tv                   → racket (0.963), shoe (0.958), collar (0.957), men (0.953), writing (0.952)
# two                  → painted (0.933), white (0.921), brown (0.917), over (0.912), dark (0.912)
# umbrella             → player (0.862), boat (0.852), along (0.845), apple (0.835), sandwich (0.833)
# under                → through (0.972), with (0.969), behind (0.966), by (0.966), small (0.964)
# up                   → big (0.969), this (0.967), has (0.966), standing (0.966), around (0.964)
# van                  → taken (0.956), racket (0.953), giraffes (0.943), board (0.942), zebras (0.941)
# vase                 → closed (0.943), pot (0.934), flower (0.933), bush (0.931), patch (0.909)
# vehicle              → wooden (0.882), tennis (0.878), screen (0.863), bird (0.862), motorcycle (0.860)
# very                 → mouse (0.899), dirt (0.867), left (0.859), view (0.854), sand (0.848)
# view                 → grey (0.898), outside (0.894), word (0.891), floor (0.875), air (0.873)
# visible              → beside (0.893), behind (0.881), near (0.872), around (0.871), old (0.871)
# walking              → fur (0.949), coat (0.943), watching (0.942), tail (0.935), wearing (0.933)
# wall                 → clock (0.939), square (0.924), lines (0.921), table (0.915), set (0.914)
# watch                → looking (0.894), there (0.880), gray (0.879), near (0.874), face (0.873)
# watching             → playing (0.965), tail (0.953), back (0.952), walking (0.942), eating (0.942)
# water                → hair (0.890), there (0.888), wet (0.882), tag (0.872), floor (0.870)
# wave                 → rock (0.909), beach (0.904), between (0.899), waves (0.872), off (0.871)
# waves                → ocean (0.941), along (0.906), rock (0.896), beach (0.885), between (0.875)
# wearing              → walking (0.933), watching (0.932), neck (0.918), ear (0.917), back (0.914)
# wears                → standing (0.926), big (0.919), at (0.914), to (0.910), up (0.907)
# wet                  → floor (0.927), reflection (0.907), by (0.906), dark (0.903), there (0.899)
# wheel                → frame (0.897), license (0.888), tire (0.887), truck (0.866), wheels (0.856)
# wheels               → seat (0.940), parked (0.895), license (0.889), stop (0.885), engine (0.878)
# white                → brown (0.973), blue (0.967), black (0.963), is (0.962), red (0.961)
# window               → mirror (0.933), set (0.927), desk (0.924), rack (0.914), end (0.906)
# windows              → brick (0.935), buildings (0.932), lines (0.922), parking (0.917), clouds (0.912)
# windshield           → signs (0.946), passenger (0.937), platform (0.934), brick (0.927), stop (0.913)
# wine                 → towel (0.947), bushes (0.932), closed (0.894), teddy (0.892), cup (0.871)
# wing                 → light (0.886), design (0.878), blue (0.875), towel (0.866), plastic (0.866)
# wire                 → middle (0.935), four (0.901), concrete (0.896), airplane (0.895), two (0.886)
# with                 → for (0.979), has (0.975), in (0.970), of (0.969), under (0.969)
# woman's              → airplane (0.826), number (0.822), cat (0.820), man (0.806), boy (0.805)
# wood                 → top (0.968), line (0.929), shelf (0.918), mirror (0.910), sky (0.908)
# wooden               → display (0.923), his (0.918), covered (0.913), tall (0.911), under (0.910)
# word                 → down (0.928), metal (0.927), dark (0.927), blue (0.922), gray (0.921)
# worn                 → behind (0.929), his (0.921), beige (0.912), over (0.911), wooden (0.908)
# wrist                → sunglasses (0.933), zebras (0.931), glasses (0.930), racket (0.923), tv (0.921)
# writing              → shoe (0.961), bananas (0.959), laptop (0.953), lettering (0.953), tv (0.952)
# yellow               → blue (0.976), pink (0.970), red (0.967), orange (0.955), black (0.948)
# young                → standing (0.951), baby (0.938), this (0.938), up (0.931), to (0.928)
# zebra                → giraffe (0.956), man's (0.946), wolf (0.922), frisbee (0.917), sheep (0.917)
# zebras               → men (0.968), racket (0.957), giraffes (0.956), lid (0.951), glasses (0.950)
#
# ✅ Displayed neighbors for 423 Visual Genome words (non-CIFAR)
